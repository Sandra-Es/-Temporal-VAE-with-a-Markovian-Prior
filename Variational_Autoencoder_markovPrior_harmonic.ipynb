# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os
import torch.nn.functional as F
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
import tensorflow as tf
import keras
from keras import ops
from keras import layers

# %% [markdown]
# ### Useful Functions

# %%
def ax_standard(ax):

    ax.grid(True, alpha=0.5)
    ax.set_xlabel("Epoch")

def plot_results(history):

    line_color = "#f07167"

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    fig.tight_layout(pad=5)

    ax[0].plot(history["loss"], color = line_color)
    ax_standard(ax[0])
    ax[0].set_ylabel("Total Loss")


    ax[1].plot(history["kl_loss"], color = line_color)
    ax_standard(ax[1])
    ax[1].set_ylabel("KL Loss")


    ax[2].plot(history["reconstruction_loss"], color = line_color)
    ax_standard(ax[2])
    ax[2].set_ylabel("Reconstruction Loss")

# %%
def plot_training_vs_validation_loss(history):
    """
    Plots the total loss, reconstruction loss, and KL divergence loss
    for both training and validation.

    Parameters:
    history: Keras history object containing training and validation loss values per epoch.
    """
    plt.figure(figsize=(10, 5))

    # Plot total loss
   # plt.plot(history.history["loss"], label="Train Loss", color="#545f66")
   # plt.plot(history.history["val_loss"], label="Validation Loss", color="#829399", linestyle="dashed")

    # Plot reconstruction loss
    plt.plot(history.history["reconstruction_loss"], label="Train Reconstruction Loss", color="#8BE4CB")
    #plt.plot(history.history["val_reconstruction_loss"], label="Validation Reconstruction Loss", color="#DAFA9E", linestyle="dashed")
    plt.xlabel("Epochs")
    plt.ylabel("Loss Value")
    plt.title("Training vs. Validation Reconstruction Loss")
    plt.legend()
    plt.grid(True)
    plt.show()
    # Plot KL loss
    plt.plot(history.history["loss"], label="Total Loss", color="#b1cc74")
    #plt.plot(history.history["val_kl_loss"], label="Validation KL Loss", color="#DAFA9E", linestyle="dashed")

    plt.xlabel("Epochs")
    plt.ylabel("Loss Value")
    plt.title("Training vs. Validation Kl_loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.plot(history.history["kl_loss"], label="KL Loss", color="#b1cc74")
    #plt.plot(history.history["val_kl_loss"], label="Validation KL Loss", color="#DAFA9E", linestyle="dashed")

    plt.xlabel("Epochs")
    plt.ylabel("Loss Value")
    plt.title("Training vs. Validation Kl_loss")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage (after training the VAE model)
# plot_training_vs_validation_loss(vae.history)  # Uncomment this after training is completed

# %%
latent_dim = 15

# %% [markdown]
# ### Paper Immplementation

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        #self.seed_generator = keras.random.SeedGenerator(3718)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        time_dim = ops.shape(z_mean)[1]
        dim = ops.shape(z_mean)[2]
        epsilon = tf.keras.backend.random_normal(shape=(batch,time_dim, dim)) #batch, time steps, latent dim
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class Sampling_t1(layers.Layer):
      def __init__(self, **kwargs):
        super().__init__(**kwargs)
        #self.seed_generator = keras.random.SeedGenerator(3718)

      def call(self, inputs):
          z_mean, z_log_var = inputs
          batch = ops.shape(z_mean)[0]
          #time_dim = ops.shape(z_mean)[1]
          dim = ops.shape(z_mean)[1]
          epsilon = tf.keras.backend.random_normal(shape=(batch, dim)) #batch,  latent dim
          return z_mean + tf.exp(0.5 * z_log_var) * epsilon
#dynamically for shape
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        epsilon = tf.random.normal(shape=tf.shape(z_mean))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
import numpy as np
import tensorflow as tf

# Generate synthetic sine wave sequences
def generate_sine_data(num_samples=1000, sequence_length=200, noise_level=0.1):
    """
    Generate sine wave sequences with slight variations.
    num_samples: Number of sequences.
    sequence_length: Number of time steps per sequence.
    noise_level: Amplitude of added random noise.
    Returns: (num_samples, sequence_length, 1) shape dataset
    """
    X = []
    for _ in range(num_samples):
        freq = np.random.uniform(0.1, 0.5)  # Random frequency
        phase = np.random.uniform(0, np.pi)  # Random phase shift
        sequence = np.sin(np.linspace(0, 2 * np.pi * freq, sequence_length) + phase)
        sequence += np.random.normal(0, noise_level, sequence_length)  # Add noise
        X.append(sequence)

    X = np.array(X).reshape(num_samples, sequence_length, 1)  # Reshape for LSTM input
    return X

# Generate data
X_train = generate_sine_data(num_samples=1000)
X_val = generate_sine_data(num_samples=200)

# Convert to TensorFlow dataset
train_dataset = tf.data.Dataset.from_tensor_slices(X_train).batch(32)
val_dataset = tf.data.Dataset.from_tensor_slices(X_val).batch(32)

print("Training Data Shape:", X_train.shape)  # (1000, 20, 1)
print("Validation Data Shape:", X_val.shape)  # (200, 20, 1)
# Out:
# Training Data Shape: (1000, 200, 1)
# Validation Data Shape: (200, 200, 1)

# %%
#Genearte noisy harmonic generator


import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def generate_harmonic_oscillator_data(num_samples=1000, sequence_length=200,
                                      mass=1.0, k_range=(0.5, 2.0),
                                      noise_level=0.05):
    """
    Generate noisy harmonic oscillator sequences.
    Returns: shape (num_samples, sequence_length, 1)
    """
    X = []
    np.random.seed(100)

    for _ in range(num_samples):
        # Random spring constant and angular frequency
        k = np.random.uniform(*k_range)
        omega = np.sqrt(k / mass)

        # Initial conditions
        pos = np.zeros(sequence_length)
        vel = np.zeros(sequence_length)
        pos[0] = np.random.uniform(-1, 1)
        vel[0] = np.random.uniform(-1, 1)

        dt = 1.0
        for t in range(1, sequence_length):
            acc = - (k / mass) * pos[t - 1]

            #euler integration
            vel[t] = vel[t - 1] + dt * acc
            pos[t] = pos[t - 1] + dt * vel[t]

            # Add noise to velocity and position
            vel[t] += np.random.normal(0, noise_level)
            pos[t] += np.random.normal(0, noise_level)

        X.append(pos)

    X = np.array(X).reshape(num_samples, sequence_length, 1)
    return X

# Generate data
X_train = generate_harmonic_oscillator_data(num_samples=1000)
X_val = generate_harmonic_oscillator_data(num_samples=200)
print("Training Data Shape:", X_train.shape)
print("Validation Data Shape", X_val.shape)
# Convert to TensorFlow dataset
#train_dataset = tf.data.Dataset.from_tensor_slices(X_train).batch(32)

# Plot a sample
plt.plot(X_train[0])
plt.title("Noisy Harmonic Oscillator Sample")
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# Training Data Shape: (1000, 200, 1)
# Validation Data Shape (200, 200, 1)

# %%
latent_dim = 15

# %%
class LatentDynamics(layers.Layer):
    def __init__(self, latent_dim, **kwargs):
        super().__init__(**kwargs)
        self.latent_dim = latent_dim

        # Trainable transition matrix A
        self.A_diag = self.add_weight(
            name='A_diag',
            shape=(latent_dim,),
            initializer=tf.keras.initializers.Ones(),  #
            trainable=True
        )


        # Trainable covariance matrix
        self.log_cov_diag = self.add_weight(
    name='log_cov_diag',
    shape=(latent_dim,),
    initializer=tf.keras.initializers.Zeros(),  # start with log(1) = 0
    trainable=True
        )




    def call(self, inputs=None):  # Added proper method signature
        cov_diag = tf.exp(self.log_cov_diag)
        return self.A_diag, cov_diag

# %%
A , cov = LatentDynamics(latent_dim)()

# %%
import random

# %%
def time_interval():

  prob = random.random()
  if prob < 0.8: #time interval [1,10] with prob 0.8
    t2 = random.randint(10,199) # max time interval is 10, so if t2 < 10 t1 will be negative if dt = 10
    t1 = random.randint(t2-10,t2-1)
  else: #time interval [1,120] with prob 0.2
    t2 = random.randint(120,199)
    t1 = random.randint(t2-120,t2-1)
    print(t1)
  return t1, t2

# %%
encoder_inputs = keras.Input(shape = (200,1))
bt = layers.LSTM(64, return_sequences = True)(encoder_inputs)
bt = layers.LSTM(32, return_sequences = True, name = 'bt')(bt) # (time, 32)
#TODO: Implement a DENSE layer to get bt instead of assuming x is bt
#belief state
# This is Pb at all times, use the time index to get Pbt1 and Pbt2
z_mean = layers.Dense(latent_dim, name = 'z_mean_t')(bt) # (time, latentDim) (20,15)
z_log_var = layers.Dense(latent_dim, name = 'z_log_var_t')(bt)

#zt2, this will directly be used in the decoder, no t2 entire thing can be passed into decoder
zt = Sampling()([z_mean, z_log_var]) #(time , latent dim samples)

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, zt, bt ], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 200, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 200, 64)   │     16,896 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bt (LSTM)           │ (None, 200, 32)   │     12,416 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean_t (Dense)    │ (None, 200, 15)   │        495 │ bt[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var_t (Dense) │ (None, 200, 15)   │        495 │ bt[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_4          │ (None, 200, 15)   │          0 │ z_mean_t[0][0],   │
# │ (Sampling)          │                   │            │ z_log_var_t[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,302 (118.37 KB)
#  Trainable params: 30,302 (118.37 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(32, activation="relu")(latent_inputs)
x = layers.Dense(64, activation="relu")(x)
decoder_outputs = layers.Dense(1, activation="sigmoid")(x)  # Predict just x_{t2}

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 15)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
smoothing_input = keras.Input(shape = (latent_dim+32+32 +1,)) #latent_dim + bt1+ bt2 + time interval
qs_mean = layers.Dense(latent_dim, name = 'qs_mean_t1')(smoothing_input) # (latentDim) (15)
qs_log_var = layers.Dense(latent_dim, name = 'qs_log_var_t1')(smoothing_input)

zt1 = Sampling()([qs_mean, qs_log_var]) #( latent dim samples)
smoothing = keras.Model(smoothing_input,[zt1,qs_mean,qs_log_var], name = "smoothing")
smoothing.summary()
# Out:
# Model: "smoothing"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 80)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ qs_mean_t1 (Dense)  │ (None, 15)        │      1,215 │ input_layer_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ qs_log_var_t1       │ (None, 15)        │      1,215 │ input_layer_10[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_5          │ (None, 15)        │          0 │ qs_mean_t1[0][0], │
# │ (Sampling)          │                   │            │ qs_log_var_t1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,430 (9.49 KB)
#  Trainable params: 2,430 (9.49 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
transition_input = keras.Input(shape = (latent_dim + 1,)) #latent dim + time interval
pt_mean = layers.Dense(latent_dim, name = 'pt_mean_t1')(transition_input) # (latentDim) (15)
pt_log_var = layers.Dense(latent_dim, name = 'pt_log_var_t1')(transition_input)

transition = keras.Model(transition_input,[pt_mean,pt_log_var], name = "transition_dense")
transition.summary()
# Out:
# Model: "transition_dense"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pt_mean_t1 (Dense)  │ (None, 15)        │        255 │ input_layer_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pt_log_var_t1       │ (None, 15)        │        255 │ input_layer_11[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 510 (1.99 KB)
#  Trainable params: 510 (1.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def log_normal_pdf(x, mean, logvar):
  return - 0.5 *(
      tf.reduce_sum(tf.math.log(2. * np.pi) + logvar + tf.square(x - mean)/ tf.exp(logvar), axis = -1)
  )

def A_poly(A, power):
    r""""
    Returns a decresing polynomial in powers of A.
    Ex: For power = 3, returns A^3 + A^2 + A + 1
    """
    if power == 0: return 1
    return pow(A,power) + A_poly(A, power-1)

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, smoothing, transition, latent_dim, transition_matrix_A, prior_covariance,  Markov_Prior =0, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.latent_dim = latent_dim
        self.smoothing = smoothing
        self.transition = transition
        self.Markov_Prior = Markov_Prior

        #self.transition_matrix_A = np.asarray([[1,0,0],[0,1,0],[0,0,2]]) #TODO: when A becomes trainable this part should be changed
        #self.prior_covariance = np.asarray([[1,0,0],[0,0.6,0],[0,0,1]])


        # Temporal prior parameters (Markovian Prior)
        #self.A = tf.convert_to_tensor(self.transition_matrix_A, dtype=tf.float32)  # Convert to Tensor
        #self.cov = tf.convert_to_tensor(self.prior_covariance, dtype=tf.float32)

        self.A = transition_matrix_A
        self.cov = prior_covariance



        # Trackers for loss components
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
      if self.Markov_Prior ==1:
        with tf.GradientTape() as tape:
        # Forward pass: Get latent variables from encoder
          z_mean, z_log_var, z, bt = self.encoder(data)

          t1, t2 = time_interval()
          bt1 = bt[:,t1,:]
          bt2 = bt[:,t2,:]
          zt2 =  z[:,t2,:]

          dt = tf.fill([tf.shape(bt1)[0], 1], tf.cast(t2 - t1, dtype=bt1.dtype))


          smoothing_inputs = tf.concat((bt1,bt2,zt2, dt), axis = -1)
          zt1, qs_mean,qs_log_var  = self.smoothing(smoothing_inputs)
          pt_mean = zt1*tf.pow(self.A,t2-t1)
          pt_log_var = tf.math.log(self.cov)*A_poly(self.A,t2-t1-1)


          #TODO: Also include the time difference/interval later to smoothinng inputs




          # Reconstruct the sequence
          reconstruction = self.decoder(zt2)
          target = data[:,t2,:]
          #print(tf.shape(reconstruction))

          # --- Reconstruction Loss ---
          #reconstruction_loss =  tf.reduce_mean(keras.losses.binary_crossentropy(target, reconstruction))

          mse = tf.keras.losses.MeanSquaredError()
          reconstruction_loss = mse(target, reconstruction)


          log_pzt1_bt1 = log_normal_pdf(zt1, z_mean[:,t1,:], z_log_var[:,t1,:])
          log_pzt2_zt1 = log_normal_pdf(zt2,  pt_mean, pt_log_var)
          log_pzt2_bt2 = log_normal_pdf(zt2, z_mean[:,t2,:], z_log_var[:,t2,:])
          log_qzt1_zt2bt1bt2 = log_normal_pdf(zt1, qs_mean,qs_log_var)

          kl_loss = log_pzt1_bt1 - log_qzt1_zt2bt1bt2

          total_kl_loss = log_pzt1_bt1 + log_pzt2_zt1 -log_pzt2_bt2  -log_qzt1_zt2bt1bt2



          total_loss = tf.reduce_mean(reconstruction_loss - total_kl_loss)





      else:
        with tf.GradientTape() as tape:
        # Forward pass: Get latent variables from encoder
          z_mean, z_log_var, z, bt = self.encoder(data)

          t1, t2 = time_interval()
          bt1 = bt[:,t1,:]
          bt2 = bt[:,t2,:]
          zt2 =  z[:,t2,:]

          dt = tf.fill([tf.shape(bt1)[0], 1], tf.cast(t2 - t1, dtype=bt1.dtype))

          smoothing_inputs = tf.concat((bt1,bt2,zt2, dt), axis = -1) #we also input the time
          zt1, qs_mean,qs_log_var  = self.smoothing(smoothing_inputs)
          pt_mean, pt_log_var = self.transition(tf.concat((zt1,dt), axis = -1))

          #TODO: Also include the time difference/interval later to smoothinng inputs




          # Reconstruct the sequence
          reconstruction = self.decoder(zt2)
          target = data[:,t2,:]
          #print(tf.shape(reconstruction))

          # --- Reconstruction Loss ---
          #reconstruction_loss =  tf.reduce_mean(keras.losses.binary_crossentropy(target, reconstruction))

          mse = tf.keras.losses.MeanSquaredError()
          reconstruction_loss = mse(target, reconstruction)


          log_pzt1_bt1 = log_normal_pdf(zt1, z_mean[:,t1,:], z_log_var[:,t1,:])
          log_pzt2_zt1 = log_normal_pdf(zt2,  pt_mean, pt_log_var)
          log_pzt2_bt2 = log_normal_pdf(zt2, z_mean[:,t2,:], z_log_var[:,t2,:])
          log_qzt1_zt2bt1bt2 = log_normal_pdf(zt1, qs_mean,qs_log_var)

          kl_loss = log_pzt1_bt1 - log_qzt1_zt2bt1bt2

          total_kl_loss = log_pzt1_bt1 + log_pzt2_zt1 -log_pzt2_bt2  -log_qzt1_zt2bt1bt2



          total_loss = tf.reduce_mean(reconstruction_loss - total_kl_loss)


            # Total loss
            #total_loss = reconstruction_loss + kl_loss
      #a =1
      # Compute gradients & update weights
      grads = tape.gradient(total_loss, self.trainable_weights)
      self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

      # Track losses TODO: uncomment this once done diagnosing
      self.total_loss_tracker.update_state(total_loss)
      self.reconstruction_loss_tracker.update_state(reconstruction_loss)
      self.kl_loss_tracker.update_state(-1*kl_loss)

      #self.total_loss_tracker.update_state(total_loss)
      #self.reconstruction_loss_tracker.update_state(reconstruction_loss)
      #self.kl_loss_tracker.update_state((quad_term))

      return {
          "loss": self.total_loss_tracker.result(),
          "reconstruction_loss": self.reconstruction_loss_tracker.result(),
          "kl_loss": self.kl_loss_tracker.result(),
      }

# %%
# Recreate the model
vae = VAE(encoder, decoder, smoothing, transition, latent_dim, A, cov, 1)
vae.compile(optimizer=keras.optimizers.Adam())

# try:
#     vae.set_weights(initial_weights)
# except:
#     initial_weights = vae.get_weights()

vae.fit(X_train, epochs=266, batch_size=128)#, validation_data=(X_val,X_val))

#vae.save_weights("markov_final_weights.weights.h5")
# Out:
# Epoch 1/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - kl_loss: 0.9287 - loss: 2.3995 - reconstruction_loss: 1.1506
# Epoch 2/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - kl_loss: 0.9302 - loss: 2.1647 - reconstruction_loss: 1.1441
# Epoch 3/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.8671 - loss: 1.9867 - reconstruction_loss: 1.1535
# Epoch 4/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.8331 - loss: 1.8376 - reconstruction_loss: 1.1034
# Epoch 5/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7689 - loss: 1.7205 - reconstruction_loss: 1.1252
# Epoch 6/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7515 - loss: 1.6976 - reconstruction_loss: 1.1264
# Epoch 7/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7495 - loss: 1.5314 - reconstruction_loss: 1.1255
# Epoch 8/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.7041 - loss: 1.4980 - reconstruction_loss: 1.1262
# Epoch 9/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6549 - loss: 1.4779 - reconstruction_loss: 1.1358
# Epoch 10/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7109 - loss: 1.4318 - reconstruction_loss: 1.1442
# Epoch 11/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6894 - loss: 1.4471 - reconstruction_loss: 1.1324
# Epoch 12/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6786 - loss: 1.3253 - reconstruction_loss: 1.1063
# Epoch 13/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6525 - loss: 1.2850 - reconstruction_loss: 1.1142
# Epoch 14/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6467 - loss: 1.3035 - reconstruction_loss: 1.1271
# Epoch 15/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6694 - loss: 1.3182 - reconstruction_loss: 1.1548
# Epoch 16/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6474 - loss: 1.2829 - reconstruction_loss: 1.1391
# Epoch 17/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7005 - loss: 1.2853 - reconstruction_loss: 1.1807
# Epoch 18/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - kl_loss: 0.6454 - loss: 1.2416 - reconstruction_loss: 1.1159
# Epoch 19/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6143 - loss: 1.1943 - reconstruction_loss: 1.1004
# Epoch 20/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6327 - loss: 1.1958 - reconstruction_loss: 1.0940
# Epoch 21/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6196 - loss: 1.1962 - reconstruction_loss: 1.1249
# Epoch 22/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6234 - loss: 1.2089 - reconstruction_loss: 1.1280
# Epoch 23/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6784 - loss: 1.2293 - reconstruction_loss: 1.1624
# Epoch 24/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6107 - loss: 1.2109 - reconstruction_loss: 1.1481
# Epoch 25/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - kl_loss: 0.6365 - loss: 1.1819 - reconstruction_loss: 1.1415
# Epoch 26/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - kl_loss: 0.5739 - loss: 1.2196 - reconstruction_loss: 1.1681
# Epoch 27/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6123 - loss: 1.1527 - reconstruction_loss: 1.1133
# Epoch 28/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - kl_loss: 0.6525 - loss: 1.2078 - reconstruction_loss: 1.1621
# Epoch 29/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - kl_loss: 0.6827 - loss: 1.2068 - reconstruction_loss: 1.1311
# Epoch 30/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - kl_loss: 0.6675 - loss: 1.1582 - reconstruction_loss: 1.1146
# Epoch 31/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.7482 - loss: 1.1887 - reconstruction_loss: 1.1209
# Epoch 32/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6182 - loss: 1.1620 - reconstruction_loss: 1.1246
# Epoch 33/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6006 - loss: 1.1811 - reconstruction_loss: 1.1291
# Epoch 34/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5857 - loss: 1.1877 - reconstruction_loss: 1.1307
# Epoch 35/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6277 - loss: 1.1695 - reconstruction_loss: 1.1283
# Epoch 36/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - kl_loss: 0.6445 - loss: 1.1893 - reconstruction_loss: 1.1354
# Epoch 37/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5462 - loss: 1.1483 - reconstruction_loss: 1.1165
# Epoch 38/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6628 - loss: 1.2171 - reconstruction_loss: 1.1836
# Epoch 39/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.7170 - loss: 1.1995 - reconstruction_loss: 1.1570
# Epoch 40/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6301 - loss: 1.1619 - reconstruction_loss: 1.1380
# Epoch 41/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6166 - loss: 1.1703 - reconstruction_loss: 1.1378
# Epoch 42/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6163 - loss: 1.1718 - reconstruction_loss: 1.1392
# Epoch 43/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5788 - loss: 1.1559 - reconstruction_loss: 1.1294
# Epoch 44/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6267 - loss: 1.0755 - reconstruction_loss: 1.0694
# Epoch 45/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5864 - loss: 1.1844 - reconstruction_loss: 1.1597
# Epoch 46/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6141 - loss: 1.2061 - reconstruction_loss: 1.1651
# Epoch 47/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6771 - loss: 1.2064 - reconstruction_loss: 1.1670
# Epoch 48/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6715 - loss: 1.1953 - reconstruction_loss: 1.1695
# Epoch 49/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6877 - loss: 1.1473 - reconstruction_loss: 1.1235
# Epoch 50/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6367 - loss: 1.1893 - reconstruction_loss: 1.1462
# Epoch 51/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6121 - loss: 1.1143 - reconstruction_loss: 1.0913
# Epoch 52/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5858 - loss: 1.1605 - reconstruction_loss: 1.1220
# Epoch 53/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5764 - loss: 1.1177 - reconstruction_loss: 1.0969
# Epoch 54/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5874 - loss: 1.1834 - reconstruction_loss: 1.1646
# Epoch 55/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5627 - loss: 1.0733 - reconstruction_loss: 1.0347
# Epoch 56/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6136 - loss: 1.1789 - reconstruction_loss: 1.1348
# Epoch 57/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6270 - loss: 1.1798 - reconstruction_loss: 1.1500
# Epoch 58/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6443 - loss: 1.2121 - reconstruction_loss: 1.1644
# Epoch 59/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5957 - loss: 1.1559 - reconstruction_loss: 1.1258
# Epoch 60/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6475 - loss: 1.1549 - reconstruction_loss: 1.1424
# Epoch 61/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6433 - loss: 1.1367 - reconstruction_loss: 1.1117
# Epoch 62/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6767 - loss: 1.1807 - reconstruction_loss: 1.1369
# Epoch 63/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6067 - loss: 1.1420 - reconstruction_loss: 1.1144
# Epoch 64/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6004 - loss: 1.1775 - reconstruction_loss: 1.1552
# Epoch 65/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5829 - loss: 1.0968 - reconstruction_loss: 1.0624
# Epoch 66/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - kl_loss: 0.6288 - loss: 1.1717 - reconstruction_loss: 1.1324
# Epoch 67/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - kl_loss: 0.5642 - loss: 1.1081 - reconstruction_loss: 1.1000
# Epoch 68/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6730 - loss: 1.1547 - reconstruction_loss: 1.1202
# Epoch 69/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - kl_loss: 0.6682 - loss: 1.0876 - reconstruction_loss: 1.0538
# Epoch 70/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - kl_loss: 0.6199 - loss: 1.2017 - reconstruction_loss: 1.1540
# Epoch 71/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - kl_loss: 0.6811 - loss: 1.1966 - reconstruction_loss: 1.1542
# Epoch 72/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6153 - loss: 1.1854 - reconstruction_loss: 1.1568
# Epoch 73/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5812 - loss: 1.1330 - reconstruction_loss: 1.0886
# Epoch 74/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6265 - loss: 1.1800 - reconstruction_loss: 1.1564
# Epoch 75/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6479 - loss: 1.1867 - reconstruction_loss: 1.1400
# Epoch 76/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6639 - loss: 1.1252 - reconstruction_loss: 1.0872
# Epoch 77/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6420 - loss: 1.2126 - reconstruction_loss: 1.1579
# Epoch 78/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6941 - loss: 1.1676 - reconstruction_loss: 1.1296
# Epoch 79/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6350 - loss: 1.1110 - reconstruction_loss: 1.0889
# Epoch 80/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.7023 - loss: 1.1639 - reconstruction_loss: 1.1401
# Epoch 81/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6781 - loss: 1.0891 - reconstruction_loss: 1.0723
# Epoch 82/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6887 - loss: 1.1749 - reconstruction_loss: 1.1347
# Epoch 83/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6304 - loss: 1.2070 - reconstruction_loss: 1.1407
# Epoch 84/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6133 - loss: 1.1330 - reconstruction_loss: 1.1013
# Epoch 85/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6694 - loss: 1.1533 - reconstruction_loss: 1.1038
# Epoch 86/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6765 - loss: 1.1034 - reconstruction_loss: 1.0692
# Epoch 87/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6381 - loss: 1.1872 - reconstruction_loss: 1.1478
# Epoch 88/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6881 - loss: 1.1018 - reconstruction_loss: 1.0816
# Epoch 89/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6483 - loss: 1.2422 - reconstruction_loss: 1.1924
# Epoch 90/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6573 - loss: 1.1997 - reconstruction_loss: 1.1721
# Epoch 91/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6192 - loss: 1.1340 - reconstruction_loss: 1.1025
# Epoch 92/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5862 - loss: 1.2065 - reconstruction_loss: 1.1819
# Epoch 93/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5771 - loss: 1.1396 - reconstruction_loss: 1.0980
# Epoch 94/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6898 - loss: 1.2098 - reconstruction_loss: 1.1748
# Epoch 95/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6092 - loss: 1.1091 - reconstruction_loss: 1.0708
# Epoch 96/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6308 - loss: 1.1790 - reconstruction_loss: 1.1408
# Epoch 97/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5771 - loss: 1.1589 - reconstruction_loss: 1.1378
# Epoch 98/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6389 - loss: 1.1987 - reconstruction_loss: 1.1722
# Epoch 99/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5718 - loss: 1.1550 - reconstruction_loss: 1.1423
# Epoch 100/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6142 - loss: 1.1275 - reconstruction_loss: 1.1130
# Epoch 101/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7135 - loss: 1.1397 - reconstruction_loss: 1.1001
# Epoch 102/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6448 - loss: 1.1503 - reconstruction_loss: 1.1303
# Epoch 103/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6132 - loss: 1.1615 - reconstruction_loss: 1.1477
# Epoch 104/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6285 - loss: 1.2284 - reconstruction_loss: 1.1933
# Epoch 105/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5871 - loss: 1.1466 - reconstruction_loss: 1.1334
# Epoch 106/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6002 - loss: 1.1977 - reconstruction_loss: 1.1659
# Epoch 107/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.6178 - loss: 1.1314 - reconstruction_loss: 1.1182
# Epoch 108/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6347 - loss: 1.1248 - reconstruction_loss: 1.1051
# Epoch 109/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - kl_loss: 0.7066 - loss: 1.1364 - reconstruction_loss: 1.1217
# Epoch 110/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - kl_loss: 0.7549 - loss: 1.1639 - reconstruction_loss: 1.1437
# Epoch 111/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - kl_loss: 0.6006 - loss: 1.1630 - reconstruction_loss: 1.1299
# Epoch 112/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - kl_loss: 0.5633 - loss: 1.1931 - reconstruction_loss: 1.1707
# Epoch 113/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - kl_loss: 0.6732 - loss: 1.1197 - reconstruction_loss: 1.0838
# Epoch 114/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - kl_loss: 0.5951 - loss: 1.1808 - reconstruction_loss: 1.1423
# Epoch 115/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - kl_loss: 0.6110 - loss: 1.1245 - reconstruction_loss: 1.0770
# Epoch 116/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - kl_loss: 0.6390 - loss: 1.1547 - reconstruction_loss: 1.1028
# Epoch 117/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - kl_loss: 0.6641 - loss: 1.1544 - reconstruction_loss: 1.1416
# Epoch 118/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - kl_loss: 0.5784 - loss: 1.2160 - reconstruction_loss: 1.1866
# Epoch 119/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - kl_loss: 0.6453 - loss: 1.2026 - reconstruction_loss: 1.1733
# Epoch 120/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - kl_loss: 0.6931 - loss: 1.1819 - reconstruction_loss: 1.1560
# Epoch 121/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - kl_loss: 0.6989 - loss: 1.0987 - reconstruction_loss: 1.0720
# Epoch 122/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - kl_loss: 0.5862 - loss: 1.1613 - reconstruction_loss: 1.1273
# Epoch 123/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6512 - loss: 1.1051 - reconstruction_loss: 1.0818
# Epoch 124/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - kl_loss: 0.6370 - loss: 1.1734 - reconstruction_loss: 1.1447
# Epoch 125/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - kl_loss: 0.6489 - loss: 1.1751 - reconstruction_loss: 1.1474
# Epoch 126/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6553 - loss: 1.1820 - reconstruction_loss: 1.1598
# Epoch 127/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.5632 - loss: 1.1781 - reconstruction_loss: 1.1531
# Epoch 128/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - kl_loss: 0.6289 - loss: 1.1607 - reconstruction_loss: 1.1288
# Epoch 129/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - kl_loss: 0.6998 - loss: 1.1185 - reconstruction_loss: 1.0928
# Epoch 130/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6008 - loss: 1.1250 - reconstruction_loss: 1.1018
# Epoch 131/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - kl_loss: 0.6590 - loss: 1.1540 - reconstruction_loss: 1.1221
# Epoch 132/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - kl_loss: 0.6987 - loss: 1.1773 - reconstruction_loss: 1.1580
# Epoch 133/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - kl_loss: 0.6755 - loss: 1.2136 - reconstruction_loss: 1.1741
# Epoch 134/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - kl_loss: 0.7199 - loss: 1.1450 - reconstruction_loss: 1.1011
# Epoch 135/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - kl_loss: 0.6340 - loss: 1.1918 - reconstruction_loss: 1.1564
# Epoch 136/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - kl_loss: 0.6488 - loss: 1.1729 - reconstruction_loss: 1.1327
# Epoch 137/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - kl_loss: 0.5967 - loss: 1.1694 - reconstruction_loss: 1.1435
# Epoch 138/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - kl_loss: 0.5948 - loss: 1.1772 - reconstruction_loss: 1.1500
# Epoch 139/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - kl_loss: 0.6431 - loss: 1.1513 - reconstruction_loss: 1.1408
# Epoch 140/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6382 - loss: 1.1465 - reconstruction_loss: 1.1023
# Epoch 141/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.5941 - loss: 1.1259 - reconstruction_loss: 1.0920
# Epoch 142/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.6446 - loss: 1.1774 - reconstruction_loss: 1.1465
# Epoch 143/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.5027 - loss: 1.1742 - reconstruction_loss: 1.1329
# Epoch 144/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - kl_loss: 0.7035 - loss: 1.1193 - reconstruction_loss: 1.0867
# Epoch 145/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - kl_loss: 0.5611 - loss: 1.2411 - reconstruction_loss: 1.2119
# Epoch 146/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6220 - loss: 1.1760 - reconstruction_loss: 1.1498
# Epoch 147/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5729 - loss: 1.1821 - reconstruction_loss: 1.1548
# Epoch 148/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5940 - loss: 1.1113 - reconstruction_loss: 1.0963
# Epoch 149/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6318 - loss: 1.2281 - reconstruction_loss: 1.1850
# Epoch 150/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.7060 - loss: 1.1146 - reconstruction_loss: 1.0841
# Epoch 151/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6662 - loss: 1.1343 - reconstruction_loss: 1.1176
# Epoch 152/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5768 - loss: 1.1532 - reconstruction_loss: 1.1267
# Epoch 153/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6524 - loss: 1.1516 - reconstruction_loss: 1.1230
# Epoch 154/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6172 - loss: 1.1793 - reconstruction_loss: 1.1416
# Epoch 155/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.5938 - loss: 1.1846 - reconstruction_loss: 1.1595
# Epoch 156/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6146 - loss: 1.2482 - reconstruction_loss: 1.2197
# Epoch 157/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6443 - loss: 1.1228 - reconstruction_loss: 1.0833
# Epoch 158/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6019 - loss: 1.1510 - reconstruction_loss: 1.1323
# Epoch 159/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6547 - loss: 1.1485 - reconstruction_loss: 1.1324
# Epoch 160/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5787 - loss: 1.2344 - reconstruction_loss: 1.1869
# Epoch 161/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6839 - loss: 1.1864 - reconstruction_loss: 1.1675
# Epoch 162/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6127 - loss: 1.1357 - reconstruction_loss: 1.1197
# Epoch 163/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6055 - loss: 1.1366 - reconstruction_loss: 1.1181
# Epoch 164/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6364 - loss: 1.2082 - reconstruction_loss: 1.1648
# Epoch 165/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6645 - loss: 1.1763 - reconstruction_loss: 1.1467
# Epoch 166/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5450 - loss: 1.1714 - reconstruction_loss: 1.1392
# Epoch 167/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5713 - loss: 1.1287 - reconstruction_loss: 1.1015
# Epoch 168/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.5768 - loss: 1.2685 - reconstruction_loss: 1.2359
# Epoch 169/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6387 - loss: 1.1248 - reconstruction_loss: 1.1000
# Epoch 170/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6980 - loss: 1.1871 - reconstruction_loss: 1.1421
# Epoch 171/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6270 - loss: 1.1617 - reconstruction_loss: 1.1459
# Epoch 172/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6164 - loss: 1.1873 - reconstruction_loss: 1.1690
# Epoch 173/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6682 - loss: 1.0887 - reconstruction_loss: 1.0492
# Epoch 174/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6462 - loss: 1.2167 - reconstruction_loss: 1.1977
# Epoch 175/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6527 - loss: 1.1734 - reconstruction_loss: 1.1502
# Epoch 176/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.5837 - loss: 1.0984 - reconstruction_loss: 1.0699
# Epoch 177/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5631 - loss: 1.1300 - reconstruction_loss: 1.1112
# Epoch 178/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6619 - loss: 1.2083 - reconstruction_loss: 1.1734
# Epoch 179/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - kl_loss: 0.5790 - loss: 1.1496 - reconstruction_loss: 1.1281
# Epoch 180/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6257 - loss: 1.1766 - reconstruction_loss: 1.1518
# Epoch 181/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6023 - loss: 1.1784 - reconstruction_loss: 1.1497
# Epoch 182/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5503 - loss: 1.1950 - reconstruction_loss: 1.1693
# Epoch 183/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6100 - loss: 1.1890 - reconstruction_loss: 1.1608
# Epoch 184/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - kl_loss: 0.6607 - loss: 1.1447 - reconstruction_loss: 1.1257
# Epoch 185/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.5702 - loss: 1.1313 - reconstruction_loss: 1.0946
# Epoch 186/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - kl_loss: 0.5929 - loss: 1.1156 - reconstruction_loss: 1.0844
# Epoch 187/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - kl_loss: 0.6786 - loss: 1.1627 - reconstruction_loss: 1.1431
# Epoch 188/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - kl_loss: 0.6123 - loss: 1.2201 - reconstruction_loss: 1.1890
# Epoch 189/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.6921 - loss: 1.1569 - reconstruction_loss: 1.1374
# Epoch 190/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.6234 - loss: 1.1466 - reconstruction_loss: 1.1318
# Epoch 191/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - kl_loss: 0.6006 - loss: 1.1878 - reconstruction_loss: 1.1530
# Epoch 192/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - kl_loss: 0.6636 - loss: 1.1848 - reconstruction_loss: 1.1381
# Epoch 193/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6083 - loss: 1.1711 - reconstruction_loss: 1.1515
# Epoch 194/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6057 - loss: 1.1837 - reconstruction_loss: 1.1459
# Epoch 195/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.7136 - loss: 1.1651 - reconstruction_loss: 1.1403
# Epoch 196/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5551 - loss: 1.1367 - reconstruction_loss: 1.1080
# Epoch 197/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5814 - loss: 1.1167 - reconstruction_loss: 1.0953
# Epoch 198/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6132 - loss: 1.1182 - reconstruction_loss: 1.1062
# Epoch 199/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6047 - loss: 1.2035 - reconstruction_loss: 1.1846
# Epoch 200/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5963 - loss: 1.1403 - reconstruction_loss: 1.1146
# Epoch 201/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6010 - loss: 1.1196 - reconstruction_loss: 1.1012
# Epoch 202/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6735 - loss: 1.1355 - reconstruction_loss: 1.1016
# Epoch 203/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6274 - loss: 1.1383 - reconstruction_loss: 1.1184
# Epoch 204/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.4902 - loss: 1.1626 - reconstruction_loss: 1.1491
# Epoch 205/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6089 - loss: 1.1266 - reconstruction_loss: 1.0955
# Epoch 206/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6907 - loss: 1.1805 - reconstruction_loss: 1.1397
# Epoch 207/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6364 - loss: 1.1679 - reconstruction_loss: 1.1394
# Epoch 208/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6438 - loss: 1.2214 - reconstruction_loss: 1.1912
# Epoch 209/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.7439 - loss: 1.1351 - reconstruction_loss: 1.1105
# Epoch 210/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.5976 - loss: 1.1198 - reconstruction_loss: 1.1029
# Epoch 211/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6068 - loss: 1.1912 - reconstruction_loss: 1.1763
# Epoch 212/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6396 - loss: 1.1782 - reconstruction_loss: 1.1736
# Epoch 213/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6236 - loss: 1.1506 - reconstruction_loss: 1.1237
# Epoch 214/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5872 - loss: 1.1814 - reconstruction_loss: 1.1496
# Epoch 215/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6431 - loss: 1.1882 - reconstruction_loss: 1.1583
# Epoch 216/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6263 - loss: 1.1667 - reconstruction_loss: 1.1358
# Epoch 217/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6280 - loss: 1.0882 - reconstruction_loss: 1.0658
# Epoch 218/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5782 - loss: 1.1528 - reconstruction_loss: 1.1210
# Epoch 219/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6097 - loss: 1.0714 - reconstruction_loss: 1.0554
# Epoch 220/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6586 - loss: 1.1998 - reconstruction_loss: 1.1511
# Epoch 221/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6433 - loss: 1.2482 - reconstruction_loss: 1.2168
# Epoch 222/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6336 - loss: 1.1098 - reconstruction_loss: 1.0804
# Epoch 223/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6743 - loss: 1.1888 - reconstruction_loss: 1.1644
# Epoch 224/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6164 - loss: 1.1430 - reconstruction_loss: 1.1092
# Epoch 225/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6132 - loss: 1.1709 - reconstruction_loss: 1.1475
# Epoch 226/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6343 - loss: 1.0883 - reconstruction_loss: 1.0693
# Epoch 227/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6643 - loss: 1.1741 - reconstruction_loss: 1.1419
# Epoch 228/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5833 - loss: 1.1709 - reconstruction_loss: 1.1459
# Epoch 229/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6664 - loss: 1.1823 - reconstruction_loss: 1.1471
# Epoch 230/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.6449 - loss: 1.1511 - reconstruction_loss: 1.1285
# Epoch 231/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - kl_loss: 0.6291 - loss: 1.1750 - reconstruction_loss: 1.1451
# Epoch 232/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.6537 - loss: 1.1598 - reconstruction_loss: 1.1267
# Epoch 233/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - kl_loss: 0.6447 - loss: 1.1373 - reconstruction_loss: 1.1197
# Epoch 234/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - kl_loss: 0.5811 - loss: 1.1792 - reconstruction_loss: 1.1494
# Epoch 235/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - kl_loss: 0.5402 - loss: 1.1300 - reconstruction_loss: 1.1092
# Epoch 236/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - kl_loss: 0.6916 - loss: 1.1788 - reconstruction_loss: 1.1510
# Epoch 237/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 0.5630 - loss: 1.0783 - reconstruction_loss: 1.0475
# Epoch 238/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6084 - loss: 1.1299 - reconstruction_loss: 1.1064
# Epoch 239/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6448 - loss: 1.1334 - reconstruction_loss: 1.1108
# Epoch 240/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6001 - loss: 1.1451 - reconstruction_loss: 1.1116
# Epoch 241/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6774 - loss: 1.1077 - reconstruction_loss: 1.0896
# Epoch 242/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6946 - loss: 1.1923 - reconstruction_loss: 1.1509
# Epoch 243/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6460 - loss: 1.1872 - reconstruction_loss: 1.1749
# Epoch 244/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6155 - loss: 1.1305 - reconstruction_loss: 1.0972
# Epoch 245/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6485 - loss: 1.1247 - reconstruction_loss: 1.0994
# Epoch 246/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6300 - loss: 1.1084 - reconstruction_loss: 1.0915
# Epoch 247/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5464 - loss: 1.1222 - reconstruction_loss: 1.0924
# Epoch 248/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6460 - loss: 1.1812 - reconstruction_loss: 1.1476
# Epoch 249/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.6269 - loss: 1.1994 - reconstruction_loss: 1.1732
# Epoch 250/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6124 - loss: 1.1661 - reconstruction_loss: 1.1372
# Epoch 251/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6189 - loss: 1.1544 - reconstruction_loss: 1.1522
# Epoch 252/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6013 - loss: 1.2005 - reconstruction_loss: 1.1694
# Epoch 253/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6317 - loss: 1.0811 - reconstruction_loss: 1.0633
# Epoch 254/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6263 - loss: 1.1708 - reconstruction_loss: 1.1335
# Epoch 255/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6275 - loss: 1.2039 - reconstruction_loss: 1.1733
# Epoch 256/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - kl_loss: 0.6076 - loss: 1.2043 - reconstruction_loss: 1.1769
# Epoch 257/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6557 - loss: 1.1761 - reconstruction_loss: 1.1556
# Epoch 258/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6501 - loss: 1.1992 - reconstruction_loss: 1.1829
# Epoch 259/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5869 - loss: 1.1986 - reconstruction_loss: 1.1595
# Epoch 260/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.5993 - loss: 1.1463 - reconstruction_loss: 1.1335
# Epoch 261/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - kl_loss: 0.5498 - loss: 1.1674 - reconstruction_loss: 1.1386
# Epoch 262/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6140 - loss: 1.1479 - reconstruction_loss: 1.1389
# Epoch 263/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.5003 - loss: 1.1592 - reconstruction_loss: 1.1427
# Epoch 264/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6573 - loss: 1.2062 - reconstruction_loss: 1.1721
# Epoch 265/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - kl_loss: 0.6047 - loss: 1.1941 - reconstruction_loss: 1.1540
# Epoch 266/266
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - kl_loss: 0.6389 - loss: 1.2019 - reconstruction_loss: 1.1475

# %%
markov_history = np.load("markov_history.npy", allow_pickle=True).item()
dense_history = np.load("dense_history.npy", allow_pickle=True).item()

markov_history.keys()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-99-3603757336.py in <cell line: 0>()
# ----> 1 markov_history = np.load("markov_history.npy", allow_pickle=True).item()
#       2 dense_history = np.load("dense_history.npy", allow_pickle=True).item()
#       3
#       4 markov_history.keys()
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453             own_fid = False
#     454         else:
# --> 455             fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456             own_fid = True
#     457
#
# FileNotFoundError: [Errno 2] No such file or directory: 'markov_history.npy'

# %%
plot_results(markov_history)

# %%
plot_results(dense_history)

# %%
plot_training_vs_validation_loss(vae.history)

# %% [markdown]
# #Test

# %% [markdown]
# we pick time t1 = 60 and sample $z_{t_{1}}$ from $P_{b}(z_{t_{1}}|b_{t1})$.

# %%
num_samples = 10
X_test = generate_sine_data(num_samples)

# %%
t1 = 60
z_mean, z_log_var, z, bt = encoder(X_test) # z shape = (1,200,latent dim)
zt1 = z[:,t1,:] #(num_samples,latent dim)
np.shape(zt1)
# Out:
# TensorShape([10, 15])

# %% [markdown]
# Then we choose the a time interval $δ_{t} = [20,100]$ to skip, sample from the forward model $P(z_{2} | z_1, δ_{t})$ to obtain $z_{t_{2}}$ at $t_2 = t_1 +  δ_{t}$

# %%
def sample_gaussian(z_mean, z_log_var):
    epsilon = tf.random.normal(shape=tf.shape(z_mean))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
def mse_loss(x,z):
  return (x-z)**2

# %%
from tqdm import tqdm

def dense_layer(X_test,t1,zt1):
  loss = []
  for dt in tqdm(range(20,139)):
    #for i in range(num_samples):
    dt1 = tf.fill([tf.shape(zt1)[0], 1], tf.cast(dt, dtype=zt1.dtype))

    zt2_mean, zt2_log_var = transition(tf.concat([zt1, dt1], axis=-1))
    zt2 = sample_gaussian(zt2_mean, zt2_log_var)
      #my transition model doesnt sample so have to do it seperately

    xt2 = decoder(zt2)

    loss.append(np.mean(mse_loss(xt2, X_test[:,t1+dt])))



  return loss


def markov_prior(X_test,t1,zt1):
  trained_A = vae.A  # shape: (latent_dim,)
  trained_cov = vae.cov  # shape: (latent_dim,)
  loss = []
  for dt in tqdm(range(20,139)):
      zt2_mean = zt1 * tf.pow(trained_A, dt)  # element-wise multiplication
      zt2_log_var = tf.math.log(trained_cov)*A_poly(trained_A,dt-1)

      zt2 = sample_gaussian(zt2_mean, zt2_log_var)
      xt2 = decoder(zt2)
      loss.append(np.mean(mse_loss(xt2, X_test[:,t1+dt])))


  return loss

# %%
markov_loss = markov_prior(X_test,t1,zt1)
# Out:
# 100%|██████████| 119/119 [00:03<00:00, 38.15it/s]

# %%
from scipy.interpolate import UnivariateSpline
x = np.arange(20, len(markov_loss) + 20)
spline = UnivariateSpline(x, markov_loss, s=10)
markov_loss_smoothed = spline(x)

plt.plot(x, markov_loss, alpha = 0.25, color="#161a1d", label="Raw Results")
plt.plot(x, markov_loss_smoothed, color = "#e5383b", label="Spline Interpolation")
plt.grid(True, alpha=0.25)
plt.xlabel("Time Skip (dt)")
plt.ylabel("MSE Loss")
plt.title("Transition: Markov Prior")
plt.legend()
plt.show()

# %%
dense_loss = dense_layer(X_test,t1,zt1)
# Out:
# 100%|██████████| 119/119 [00:00<00:00, 123.58it/s]

# %%
plt.plot(dense_loss)

# %%
# Generate Sample Preds

def markov_gen(X_test,t1,zt1):
  trained_A = vae.A  # shape: (latent_dim,)
  trained_cov = vae.cov  # shape: (latent_dim,)
  loss = []
  for dt in tqdm(range(20,139)):
      zt2_mean = zt1 * tf.pow(trained_A, dt)  # element-wise multiplication
      zt2_log_var = tf.math.log(trained_cov)*A_poly(trained_A,dt-1)

      zt2 = sample_gaussian(zt2_mean, zt2_log_var)
      xt2 = decoder(zt2)

  return xt2

preds_markov = markov_gen(X_test, t1, zt1)
preds_markov.shape
# Out:
# 100%|██████████| 119/119 [00:02<00:00, 39.71it/s]
# TensorShape([10, 1])

# %%
plt.plot(X_test[0])
